# %% [markdown]
# # Exploring  dataset on the job outcomes of students who graduated from college between 2010 and 2012
#
# In this project, I will be working with a dataset on the job outcomes of students who graduated from college between 2010 and 2012. The original data on job outcomes was released by American Community Survey, which conducts surveys and aggregates the data. FiveThirtyEight cleaned the dataset and released it on their [Github](https://github.com/fivethirtyeight/data/tree/master/college-majors) repo.
#
# Each row in the dataset represents a different major in college and contains information on gender diversity, employment rates, median salaries, and more. Here are some of the columns in the dataset:
#
# * `Rank` - Rank by median earnings (the dataset is ordered by this column).
# * `Major_code` - Major code.
# * `Major` - Major description.
# * `Major_category` - Category of major.
# * `Total` - Total number of people with major.
# * `Sample_size` - Sample size (unweighted) of full-time.
# * `Men` - Male graduates.
# * `Women` - Female graduates.
# * `ShareWomen` - Women as share of total.
# * `Employed` - Number employed.
# * `Median` - Median salary of full-time, year-round workers.
# * `Low_wage_jobs` - Number in low-wage service jobs.
# * `Full_time` - Number employed 35 hours or more.
# * `Part_time` - Number employed less than 35 hours.
#
# Using visualizations we can start to explore the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  ...  \
# 168    Biology & Life Science    0.637293           47      6259  ...
# 169  Psychology & Social Work    0.817099            7      2125  ...
# 170  Psychology & Social Work    0.799859           13      2101  ...
# 171  Psychology & Social Work    0.798746           21      3777  ...
# 172                 Education    0.877960            2       742  ...
#
#      Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = recent_grads
raw_data_count
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
recent_grads = recent_grads.dropna()
recent_grads
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
recent_grads.plot(x='Sample_size', 
y='Median',kind='scatter', title='Median vs. Sample_size')

# %% [markdown]
# From the above scatter plot, shows a weak correlation between median salary of full-time, year-round workers and the sample size of full time. There two outliers at over 4000 sample at approx 40k and at 100 sample size at over 100k.

# %%
recent_grads.plot(x='Sample_size',y='Unemployment_rate',
kind='scatter',title='Unemployment_rate vs. Sample_size')

# %% [markdown]
# From the above scatter plot, also shows a weak correlation between Unemployment rate and the sample size of full time.

# %%
recent_grads.plot(x='Full_time', 
y='Median',kind='scatter', title='Full_time vs. Median')

# %% [markdown]
# From the above scatter plot, also shows a weak correlation between the number employed 35 hours or more and median salary of full-time, year-round workers

# %%
recent_grads.plot(x='ShareWomen',y='Unemployment_rate',
kind='scatter', title='ShareWomen vs. Unemployment_rate')

# %% [markdown]
# From the above scatter plot, shows no correlation between the women as share of total and the number employed 35 hours or more.

# %%
recent_grads.plot(x='Men',y='Median',
kind='scatter', title='Men vs. Median')

# %%
recent_grads.plot(x='Women',y='Median',
kind='scatter', title='Women vs. Median')

# %% [markdown]
# Weak correlation for both the male and the female gradutes and the median salary of full-time, year-round workers. A majority of male and female graduates have median salaries ranging from 20000 to less than 80,000.

# %%
recent_grads.plot(x='Major_code',y='Median',
kind='scatter', title='Major_code vs. Median')
# recent_grads[['Major_code', 'Median']].plot.bar()
# recent_grads.plot.bar(x='Major_code', y='Median', legend = False)
recent_grads['Major_category'].unique()
# Out:
# array(['Engineering', 'Business', 'Physical Sciences',
#        'Law & Public Policy', 'Computers & Mathematics',
#        'Industrial Arts & Consumer Services', 'Arts', 'Health',
#        'Social Science', 'Biology & Life Science', 'Education',
#        'Agriculture & Natural Resources', 'Humanities & Liberal Arts',
#        'Psychology & Social Work', 'Communications & Journalism',
#        'Interdisciplinary'], dtype=object)

# %%
# cols = ['Sample_size',
# 'Median',
# 'Employed',
# 'Full_time',
# 'ShareWomen',
# 'Unemployment_rate',
# 'Men',
# 'Women',]
# fig = plt.figure(figsize=(10,6))

# for i in range(0, 8):
#     ax = fig.add_subplot(8,1,i+1)
#     recent_grads[cols[i]].hist()
# plt.show()

# %%
recent_grads['Sample_size'].hist(bins = 10, range=(0,5000))

# %%
# recent_grads['Median'].plot(kind='hist')
recent_grads['Median'].hist(range = (30000,40000))

# %% [markdown]
# The common median earnings of full-time, year-round workers, ranges from 35k to 36k

# %%
recent_grads['Employed'].hist()

# %%
recent_grads['Full_time'].hist()

# %%
recent_grads['ShareWomen'].hist()

# %%
recent_grads['Unemployment_rate'].hist()

# %%
recent_grads['Men'].hist(bins=25, range=(0,35000))

# %%
recent_grads['Women'].hist(bins=25, range=(0,35000))

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe2780557b8>,
# ...
#       dtype=object)

# %%
scatter_matrix(
recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe278406898>,
# ...
#       dtype=object)

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
recent_grads[162:].plot.bar(x='Major', y='Unemployment_rate')

# %% [markdown]
# In the first ten, the major with the highest unemployment is Nuclear Engineering with 17.5% while in the last ten, Clinical Psychology is the highest with 13%.

# %%
recent_grads[:10].plot.bar(x='Major', y='Men')
recent_grads[:10].plot.bar(x='Major', y='Women')

# %% [markdown]
# In the first ten, there are more women and men in Electrical, Chemical and Mechanical Engineering than in the other majors. However, there are far more male gradutes for this majors than there are female graduates.
